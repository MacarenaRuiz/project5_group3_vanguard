# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Loading the housing price dataset (assuming the file name is "housing_price.csv")
import pandas as pd
# 1 TABLE --> df_final_demo
df1 = pd.read_csv("data/raw/df_final_demo.txt")
df1.shape
# Out:
# (70609, 9)

# %%
#df_final_demo (File 1)
df1.head()
# Out:
#    client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0     836976             6.0              73.0      60.5     U        2.0
# 1    2304905             7.0              94.0      58.0     U        2.0
# 2    1439522             5.0              64.0      32.0     U        2.0
# 3    1562045            16.0             198.0      49.0     M        2.0
# 4    5126305            12.0             145.0      33.0     F        2.0
#
#          bal  calls_6_mnth  logons_6_mnth
# 0   45105.30           6.0            9.0
# 1  110860.30           6.0            9.0
# 2   52467.79           6.0            9.0
# 3   67454.65           3.0            6.0
# 4  103671.75           0.0            3.0

# %%
#Data Cleaning for df_final_demo.txt
df1.nunique()
# Out:
# client_id           70609
# clnt_tenure_yr         54
# clnt_tenure_mnth      482
# clnt_age              165
# gendr                   4
# num_accts               8
# bal                 70328
# calls_6_mnth            8
# logons_6_mnth           9
# dtype: int64

# %%
df1.gendr.unique()
#df1['gendr'].fillna(' ')
df1['gendr'].value_counts()

#Replace gendr X and U for nothing
df1['gendr'] = df1['gendr'].replace({'X': ' ', 'U': ' '})
df1['gendr'].value_counts()
# Out:
# gendr
#      24125
# M    23724
# F    22746
# Name: count, dtype: int64

# %%
# 2 TABLE --> df_final_web_data_pt_1

# %%
import pandas as pd
df2 = pd.read_csv("data/raw/df_final_web_data_pt_1.txt")
df2.shape
# Out:
# (343141, 5)

# %%
#df_final_web_data_pt_1 (File 3)
df2.head()
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time
# 0  2017-04-17 15:27:07
# 1  2017-04-17 15:26:51
# 2  2017-04-17 15:19:22
# 3  2017-04-17 15:19:13
# 4  2017-04-17 15:18:04

# %%
#number of clients id
df2.nunique()
#df2.client_id.nunique()
# Out:
# client_id        58391
# visitor_id       62936
# visit_id         75256
# process_step         5
# date_time       282666
# dtype: int64

# %%
import pandas as pd
df3 = pd.read_csv("data/raw/df_final_web_data_pt_2.txt")
df3.shape
# Out:
# (412264, 5)

# %%
#df_final_web_data_pt_2 (File 4)
df3.head()
# Out:
#    client_id             visitor_id                      visit_id  \
# 0     763412  601952081_10457207388  397475557_40440946728_419634
# 1    6019349  442094451_91531546617  154620534_35331068705_522317
# 2    6019349  442094451_91531546617  154620534_35331068705_522317
# 3    6019349  442094451_91531546617  154620534_35331068705_522317
# 4    6019349  442094451_91531546617  154620534_35331068705_522317
#
#   process_step            date_time
# 0      confirm  2017-06-06 08:56:00
# 1      confirm  2017-06-01 11:59:27
# 2       step_3  2017-06-01 11:58:48
# 3       step_2  2017-06-01 11:58:08
# 4       step_1  2017-06-01 11:57:58

# %%
df3.nunique()
#df3['client_id'].isnull()
df3.isna().any()
# Out:
# client_id       False
# visitor_id      False
# visit_id        False
# process_step    False
# date_time       False
# dtype: bool

# %%
#concat df2 and df3
#pd.concat([df2_client_id, df3_client_id], axis=1)
new_df2_df3 = pd.concat([df2, df3], axis=0)
display(new_df2_df3)
new_df2_df3.nunique()
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# 1            step_2  2017-04-17 15:26:51
# 2            step_3  2017-04-17 15:19:22
# 3            step_2  2017-04-17 15:19:13
# 4            step_3  2017-04-17 15:18:04
# ...             ...                  ...
# 412259        start  2017-05-24 18:46:10
# 412260        start  2017-05-24 18:45:29
# 412261       step_1  2017-05-24 18:44:51
# 412262        start  2017-05-24 18:44:34
# 412263        start  2017-06-03 12:17:09
#
# [755405 rows x 5 columns]
# client_id       120157
# visitor_id      130236
# visit_id        158095
# process_step         5
# date_time       629363
# dtype: int64

# %%
# Loading the housing price dataset (assuming the file name is "housing_price.csv")
import pandas as pd
df4 = pd.read_csv("data/raw/df_final_experiment_clients.txt")
df4.shape
# Out:
# (70609, 2)

# %%
#df_final_experiment_clients (File 2)
df4.head()
# Out:
#    client_id Variation
# 0    9988021      Test
# 1    8320017      Test
# 2    4033851   Control
# 3    1982004      Test
# 4    9294070   Control

# %%
df4.nunique()
df4.client_id.nunique()
#df4.Variation.nunique()
#df4.isnull()
df4.isna().sum()
# Out:
# client_id        0
# Variation    20109
# dtype: int64

# %%
#concat df1(client_id, clnt_tenure_yr, clnt_tenure_mon, clnt_age, gend, num_accts, bal, cal_6_mnths, logons_6_mnths) + df4(client_id, variation)
new_df1_df4 = pd.merge(df1, df4)
display(new_df1_df4)
new_df1_df4.nunique()
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5              2.0
# 1        2304905             7.0              94.0      58.0              2.0
# 2        1439522             5.0              64.0      32.0              2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5              3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
#               bal  calls_6_mnth  logons_6_mnth Variation
# 0        45105.30           6.0            9.0      Test
# 1       110860.30           6.0            9.0   Control
# 2        52467.79           6.0            9.0      Test
# 3        67454.65           3.0            6.0      Test
# 4       103671.75           0.0            3.0   Control
# ...           ...           ...            ...       ...
# 70604  1411062.68           5.0            5.0       NaN
# 70605   101867.07           6.0            6.0       NaN
# 70606    40745.00           3.0            3.0       NaN
# 70607   475114.69           4.0            4.0       NaN
# 70608   157498.73           7.0            7.0       NaN
#
# [70609 rows x 10 columns]
# client_id           70609
# clnt_tenure_yr         54
# clnt_tenure_mnth      482
# clnt_age              165
# gendr                   3
# num_accts               8
# bal                 70328
# calls_6_mnth            8
# logons_6_mnth           9
# Variation               2
# dtype: int64

# %%
#df1.gendr.unique()
#df1['gendr'].fillna(' ')
new_df1_df4['gendr'].value_counts()

#Replace gendr X and U for nothing
#new_df1_df4['gendr'] = df1['gendr'].replace({'X': ' ', 'U': ' '})
#df1['gendr'].value_counts()
# Out:
# gendr
#      24125
# M    23724
# F    22746
# Name: count, dtype: int64

# %%
#To convert 'new_df1_df4' in CSV (df_1 -> final demo and df_4 -> final experiment)
new_df1_df4.to_csv('new_df1_df4. csv', index=False)

# %%
#We are changing columns names: 'gendr': 'gender', 'num_accts': 'number_of_accounts', 'bal': 'balance'
new_df1_df4.rename(columns={'gendr': 'gender', 'num_accts': 'number_of_accounts', 'bal': 'balance'},inplace=True)

# %%
# TOP10 clients by balance amount
df1_4_sorted = new_df1_df4.sort_values(by='balance', ascending=False)
top_10_values = df1_4_sorted.head(10)
top_10_values
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gender  \
# 39367    9286288            21.0             254.0      62.5      M
# 63746    8339240             6.0              80.0      26.5      M
# 23849    7070097            11.0             133.0      53.0      M
# 13318    9440656             7.0              94.0      63.0      F
# 2171     2291985             7.0              85.0      41.0      M
# 20871    1678193            24.0             299.0      65.5      M
# 31811    6762377            16.0             193.0      41.5      F
# 14057    3519657            18.0             218.0      66.5      M
# 21184     987970            14.0             179.0      74.5      M
# 33222     857273            31.0             376.0      56.5      M
#
#        number_of_accounts      balance  calls_6_mnth  logons_6_mnth Variation
# 39367                 3.0  16320040.15           6.0            9.0      Test
# 63746                 2.0  12838418.01           3.0            3.0       NaN
# 23849                 2.0   8986419.77           6.0            9.0      Test
# 13318                 2.0   8292996.21           6.0            9.0   Control
# 2171                  2.0   8247729.97           1.0            4.0   Control
# 20871                 3.0   8137343.24           6.0            9.0      Test
# 31811                 3.0   8045102.60           6.0            9.0      Test
# 14057                 6.0   7741994.01           6.0            9.0   Control
# 21184                 3.0   7339443.17           4.0            9.0   Control
# 33222                 5.0   6716305.28           6.0            9.0   Control

# %%
#Describing clnt_tenure_yr and clnt_age
new_df1_df4[['clnt_tenure_yr','clnt_age']].describe()
# Out:
#        clnt_tenure_yr      clnt_age
# count    70595.000000  70594.000000
# mean        12.052950     46.442240
# std          6.871819     15.591273
# min          2.000000     13.500000
# 25%          6.000000     32.500000
# 50%         11.000000     47.000000
# 75%         16.000000     59.000000
# max         62.000000     96.000000

# %%
new_df1_df4['gender'].value_counts()
# Out:
# gender
#      24125
# M    23724
# F    22746
# Name: count, dtype: int64

# %%
new_df1_df4.Variation.unique()
new_df1_df4['Variation'].value_counts()

#to count how many nan I do have
new_df1_df4.isna().sum()
# Out:
# client_id                 0
# clnt_tenure_yr           14
# clnt_tenure_mnth         14
# clnt_age                 15
# gender                   14
# number_of_accounts       14
# balance                  14
# calls_6_mnth             14
# logons_6_mnth            14
# Variation             20109
# dtype: int64

# %%
#We have dreopped these 20109 lines rows with NAN, we had 70609 and now we have: 50487
new_df1_df4.dropna(inplace=True)
new_df1_df4['Variation'].value_counts()
new_df1_df4.shape
# Out:
# (50487, 10)

# %%
#DAY2 
#client behavior analysis
# I am going to use  this df: new_df2_df3  process_step	| client_id
#1. Who are the primary clients using this online process?
#2. Are the primary clients younger or older, new or long-standing?
top10_client_id = new_df2_df3['client_id'].value_counts().iloc[:10].index
fig, axes = plt.subplots(figsize=(4,6))
sns.barplot(data=new_df2_df3[ new_df2_df3['client_id'].isin(top10_client_id)], x='process_step', y='client_id', palette="coolwarm", ax=axes);
# Out:
# C:\Users\macar\AppData\Local\Temp\ipykernel_37244\1257062160.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=new_df2_df3[ new_df2_df3['client_id'].isin(top10_client_id)], x='process_step', y='client_id', palette="coolwarm", ax=axes);

# %%
#To convert 'new_df2_df3' in CSV (df_2 -> web_data_pt_1 ,  df_3 -> web_data_pt_2
new_df2_df3.to_csv('new_df2_df3. csv', index=False)

# %%
#
fig, axes = plt.subplots()
sns.histplot(new_df1_df4['clnt_tenure_yr'], kde=True, bins=30, color="salmon", ax=axes);
plt.show()

# %%
new_df1_df4.describe()
# Out:
#           client_id  clnt_tenure_yr  clnt_tenure_mnth      clnt_age  \
# count  5.048700e+04    50487.000000      50487.000000  50487.000000
# mean   5.006180e+06       12.031810        150.416365     47.319795
# std    2.877445e+06        6.860326         81.945403     15.518616
# min    5.550000e+02        2.000000         33.000000     17.000000
# 25%    2.515688e+06        6.000000         82.000000     33.500000
# 50%    5.025043e+06       11.000000        136.000000     48.000000
# 75%    7.477922e+06       16.000000        192.000000     59.500000
# max    9.999832e+06       55.000000        669.000000     96.000000
#
#        number_of_accounts       balance  calls_6_mnth  logons_6_mnth
# count        50487.000000  5.048700e+04  50487.000000   50487.000000
# mean             2.254580  1.495168e+05      3.093272       6.131856
# std              0.533675  3.020390e+05      2.188009       2.175441
# min              1.000000  2.378944e+04      0.000000       3.000000
# 25%              2.000000  3.987718e+04      1.000000       4.000000
# 50%              2.000000  6.573433e+04      3.000000       6.000000
# 75%              2.000000  1.399583e+05      5.000000       8.000000
# max              7.000000  1.632004e+07      6.000000       9.000000

# %%
#2. Are the primary clients younger or older, new or long-standing?

# %%
#DAY 3 SUCCESS INDICATORS

#Completion Rate: 
#1. to order by client_id and date_time
new_df2_df3 = new_df2_df3.sort_values(by=['client_id', 'date_time'])

#2. To calculate the next step for each user
new_df2_df3['next_step'] = new_df2_df3.groupby('client_id')['process_step'].shift(-1)

#3. To check if went back
new_df2_df3['error_backstep'] = new_df2_df3['next_step'] < new_df2_df3['process_step']
#this creates a col booleana T/F

#number of errors per step
error_count_by_step = new_df2_df3.groupby('process_step')['error_backstep'].sum()
print(error_count_by_step.sort_values(ascending=False))
# Out:
# process_step
# step_3     102721
# step_1      28577
# step_2      20428
# start         284
# confirm         0
# Name: error_backstep, dtype: int64

# %%
#1. Completion Rate
#-This line filters users who reached the “confirm” step, which is considered the final step of the funnel.
#-It then counts how many users reached this step using groupby().size().
#-This gives you the completion rate: how many users finished the process.

# %%
#DAY 3 SUCCESS INDICATORS

#2  TIME SPENT ON EACH STEP
#new_df2_df3['client_id'].value_counts()
#new_df2_df3['visitor_id'].value_counts()
#new_df2_df3['visit_id'].value_counts()

#Completion rate: The total users who reach the final 'confirm step' were 102963
#new_df2_df3['process_step'].value_counts()

#2 Time spent on each step: 
#to calculate the average date_time of each step

#1. Ensure date_time is in datetime format
new_df2_df3['date_time'] = pd.to_datetime(new_df2_df3['date_time'])

# 2. Sort by user and time
new_df2_df3 = new_df2_df3.sort_values(by=['client_id', 'date_time'])
# 3. Calculate time difference to next row per user (new columns time_spent is added)
new_df2_df3['time_spent'] = new_df2_df3.groupby('client_id')['date_time'].shift(-1) - new_df2_df3['date_time']

# 4. Compute average time spent per process_step 
avg_time_per_step = new_df2_df3.groupby('process_step')['time_spent'].mean()

print(avg_time_per_step)

#testing
#print(new_df2_df3.columns)
#print(new_df2_df3['date_time'].dtype)
#print(new_df2_df3['date_time'].isnull().sum())
#print(new_df2_df3['process_step'].unique())
#print(new_df2_df3[['client_id', 'process_step', 'date_time', 'time_spent']].head(10))
# Out:
# process_step
# confirm   3 days 00:13:54.903339743
# start     0 days 22:57:48.680451110
# step_1    0 days 09:20:59.881194241
# step_2    0 days 05:14:25.662991014
# step_3    0 days 09:01:39.903402084
# Name: time_spent, dtype: timedelta64[ns]

# %%
#2. Time Spent on Each Step
#For each user session, the code calculates the timestamp of the next step.
#Then it calculates the time difference between the current and next step in seconds.
#This allows us to calculate the average time spent on each step of the process.

# %%
#DAY 3 SUCCESS INDICATORS
# Error Rates: If there's a step where users go back to a previous step, it may indicate confusion or an error. You should consider moving from a later step to an earlier one as an error.
#%
error_percentage_by_step = new_df2_df3.groupby('process_step')['error_backstep'].mean() * 100
# Mostrar el resultado ordenado
print(error_percentage_by_step.sort_values(ascending=False))
# Out:
# process_step
# step_3     91.517436
# step_1     17.511168
# step_2     15.352242
# start       0.116420
# confirm     0.000000
# Name: error_backstep, dtype: float64

# %%
#3. Error Rate (Step Reversals)
#The process_step is mapped to numeric order (step_1 = 1, step_2 = 2, etc.) so it can be compared.
#If the next step number is less than the current one, it means the user went backwards — possibly due to confusion or error.
#These are counted as errors with a value of 1.
#Later, the average error rate per step or variation is calculated.

# %%
# DAY3
#CONTROL is old one, Test is the new one
# Based on the chosen KPIs, how does the new design's performance compare to the old one?

# --- STEP 1: Merge table1 and table2 on client_id ---
df2_3_4 = new_df2_df3.merge(df4, on='client_id', how='left')
# Ensure datetime is parsed correctly
df2_3_4['date_time'] = pd.to_datetime(df2_3_4['date_time'])

# %%
#to dropna variation
df2_3_4['Variation'].isna().sum()
df2_3_4.dropna(inplace=True)

# %%
#to check how many we have of variation in df2_3_4
df2_3_4['Variation'].value_counts()
df2_3_4['Variation'].isna().sum()
# Out:
# np.int64(0)

# %%
#variation have 270 809 rows
df2_3_4.shape
# Out:
# (270809, 9)

# %%
#To convert 'new_df1_df4' in CSV (df_1 -> final demo and df_4 -> final experiment)
new_df1_df4.to_csv('new_df1_df4. csv', index=False)

# %%
#To convert 'df2_3_4' in CSV (df2 -> web_data_pt_1 ,  df3 -> web_data_pt_2 , df4 -> final_experiment_clients)
#df2_3_4 
df2_3_4.to_csv('df2_3_4.to_csv', index=False)

# %%
#To convert 'new_df1_df4' in CSV (df_1 -> final demo and df_4 -> final experiment)
new_df1_df4.to_csv('new_df1_df4. csv', index=False)

# %%
df_1_2_3_4 = df2_3_4.merge(df1, on='client_id', how='left')
display(df_1_2_3_4)
# Out:
#         client_id             visitor_id                      visit_id  \
# 0             555  402506806_56087378777  637149525_38041617439_716659
# 1             555  402506806_56087378777  637149525_38041617439_716659
# 2             555  402506806_56087378777  637149525_38041617439_716659
# 3             555  402506806_56087378777  637149525_38041617439_716659
# 4             647   66758770_53988066587   40369564_40101682850_311847
# ...           ...                    ...                           ...
# 270804    9999729  834634258_21862004160  870243567_56915814033_814203
# 270805    9999729  834634258_21862004160  870243567_56915814033_814203
# 270806    9999729  834634258_21862004160  870243567_56915814033_814203
# 270807    9999729  834634258_21862004160  870243567_56915814033_814203
# 270808    9999832  145538019_54444341400  472154369_16714624241_585315
#
#        process_step           date_time next_step  error_backstep  \
# 0             start 2017-04-15 12:57:56    step_1           False
# 1            step_1 2017-04-15 12:58:03    step_2           False
# 2            step_2 2017-04-15 12:58:35    step_3           False
# 3            step_3 2017-04-15 13:00:14   confirm            True
# 4             start 2017-04-12 15:41:28    step_1           False
# ...             ...                 ...       ...             ...
# 270804        start 2017-05-08 16:08:25    step_1           False
# 270805       step_1 2017-05-08 16:08:30    step_2           False
# 270806       step_2 2017-05-08 16:08:40    step_3           False
# 270807       step_3 2017-05-08 16:09:19   confirm            True
# 270808        start 2017-05-16 16:46:03    step_1           False
#
#             time_spent Variation  clnt_tenure_yr  clnt_tenure_mnth  clnt_age  \
# 0      0 days 00:00:07      Test             3.0              46.0      29.5
# 1      0 days 00:00:32      Test             3.0              46.0      29.5
# 2      0 days 00:01:39      Test             3.0              46.0      29.5
# 3      0 days 00:00:20      Test             3.0              46.0      29.5
# 4      0 days 00:00:07      Test            12.0             151.0      57.5
# ...                ...       ...             ...               ...       ...
# 270804 0 days 00:00:05      Test            10.0             124.0      31.0
# 270805 0 days 00:00:10      Test            10.0             124.0      31.0
# 270806 0 days 00:00:39      Test            10.0             124.0      31.0
# 270807 0 days 00:00:21      Test            10.0             124.0      31.0
# 270808 0 days 00:00:08      Test            23.0             281.0      49.0
#
#        gendr  num_accts        bal  calls_6_mnth  logons_6_mnth
# 0          U        2.0   25454.66           2.0            6.0
# 1          U        2.0   25454.66           2.0            6.0
# 2          U        2.0   25454.66           2.0            6.0
# 3          U        2.0   25454.66           2.0            6.0
# 4          M        2.0   30525.80           0.0            4.0
# ...      ...        ...        ...           ...            ...
# 270804     F        3.0  107059.74           6.0            9.0
# 270805     F        3.0  107059.74           6.0            9.0
# 270806     F        3.0  107059.74           6.0            9.0
# 270807     F        3.0  107059.74           6.0            9.0
# 270808     F        2.0  431887.61           1.0            4.0
#
# [270809 rows x 17 columns]

# %%
#To convert to csv df_1_2_3_4 
df_1_2_3_4.to_csv('df_1_2_3_4. csv', index=False)

# %%
new_df1_df4['Variation'].isna().sum()
# Out:
# np.int64(0)

# %%
df_final=new_df2_df3.merge(df4, on='client_id', how='left')
df_final.shape
# Out:
# (755405, 9)

# %%
#concat df1, df2 and df3
#pd.concat([df1dinal_demo, df2_client_id, df3_client_id], axis=1)
new_df1_df2_df3= pd.concat([df1, df2, df3], axis=0)
display(new_df1_df2_df3)
new_df1_df2_df3.nunique()
# Out:
#         client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  \
# 0          836976             6.0              73.0      60.5     U
# 1         2304905             7.0              94.0      58.0     U
# 2         1439522             5.0              64.0      32.0     U
# 3         1562045            16.0             198.0      49.0     M
# 4         5126305            12.0             145.0      33.0     F
# ...           ...             ...               ...       ...   ...
# 412259    9668240             NaN               NaN       NaN   NaN
# 412260    9668240             NaN               NaN       NaN   NaN
# 412261    9668240             NaN               NaN       NaN   NaN
# 412262    9668240             NaN               NaN       NaN   NaN
# 412263     674799             NaN               NaN       NaN   NaN
#
#         num_accts        bal  calls_6_mnth  logons_6_mnth  \
# 0             2.0   45105.30           6.0            9.0
# 1             2.0  110860.30           6.0            9.0
# 2             2.0   52467.79           6.0            9.0
# 3             2.0   67454.65           3.0            6.0
# 4             2.0  103671.75           0.0            3.0
# ...           ...        ...           ...            ...
# 412259        NaN        NaN           NaN            NaN
# 412260        NaN        NaN           NaN            NaN
# 412261        NaN        NaN           NaN            NaN
# 412262        NaN        NaN           NaN            NaN
# 412263        NaN        NaN           NaN            NaN
#
#                    visitor_id                     visit_id process_step  \
# 0                         NaN                          NaN          NaN
# 1                         NaN                          NaN          NaN
# 2                         NaN                          NaN          NaN
# 3                         NaN                          NaN          NaN
# 4                         NaN                          NaN          NaN
# ...                       ...                          ...          ...
# 412259   388766751_9038881013  922267647_3096648104_968866        start
# 412260   388766751_9038881013  922267647_3096648104_968866        start
# 412261   388766751_9038881013  922267647_3096648104_968866       step_1
# 412262   388766751_9038881013  922267647_3096648104_968866        start
# 412263  947159805_81558194550  86152093_47511127657_716022        start
#
#                   date_time
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 412259  2017-05-24 18:46:10
# 412260  2017-05-24 18:45:29
# 412261  2017-05-24 18:44:51
# 412262  2017-05-24 18:44:34
# 412263  2017-06-03 12:17:09
#
# [826014 rows x 13 columns]
# client_id           120157
# clnt_tenure_yr          54
# clnt_tenure_mnth       482
# clnt_age               165
# gendr                    4
# num_accts                8
# bal                  70328
# calls_6_mnth             8
# logons_6_mnth            9
# visitor_id          130236
# visit_id            158095
# process_step             5
# date_time           629363
# dtype: int64

# %%
#To convert 'new_df1_df2_df3' in CSV 
new_df1_df2_df3.to_csv('new_df1_df2_df3. csv', index=False)
